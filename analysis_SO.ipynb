# %%
import pandas as pd

df = pd.read_csv('stat_rep_answer.csv')

# %%
df = df.sort_values(by = 'RepCap')
#df = df[df.RepCap.isin([0,50000,100000,150000,200000,250000,300000,350000,400000])]

# %%
df.head()
# Out:
#    RepCap  Num_User   Num_Ans
# 0       0  17053422  32756847
# 1   50000      3087   5649144
# 2  100000      1092   3584549
# 3  150000       563   2585748
# 4  200000       347   1964499

# %%
# df['Frac_User'] = df['Num_User']/df[df.RepCap==0].iloc[0]['Num_User']
# df['Frac_Ans'] = df['Num_Ans']/df[df.RepCap==0].iloc[0]['Num_Ans']
# df.head()

# %%
import matplotlib.pyplot as plt

plt.plot(df['RepCap'],df['Num_Ans'],marker='o')

# %%
df = pd.read_csv('freq_plot_data.csv')
df = df.sort_values(by='Frac_User')

#df['Tot_User'] = 4222004 #total if reputation 1 users are ignored
#df['Tot_Ans'] = 32101441 #total if reputation 1 users are ignored
#df = df[df.Rep_Cap>0]

df['Frac_User'] = (df['Num_User_Rep']/df['Tot_User'])*100
df['Frac_Ans'] = (df['Num_Ans_Rep']/df['Tot_Ans'])*100

df
# Out:
#     Num_Ans_Rep   Tot_Ans  Num_User_Rep  Tot_User   Frac_Ans   Frac_User  \
# 0        165053  33098233             4  17053422   0.498676    0.000023
# 1       3584549  33098233          1092  17053422  10.830031    0.006403
# 2      12257130  33098233         24894  17053422  37.032581    0.145977
# 3      21359160  33098233        171987  17053422  64.532629    1.008519
# 4      23106201  33098233        242731  17053422  69.810981    1.423357
# 5      25115466  33098233        366102  17053422  75.881592    2.146795
# 6      25776157  33098233        421002  17053422  77.877744    2.468724
# 7      26541380  33098233        497052  17053422  80.189719    2.914676
# 8      27457992  33098233        619500  17053422  82.959087    3.632702
# 9      27951264  33098233        714071  17053422  84.449415    4.187259
# 10     29426492  33098233       1142827  17053422  88.906535    6.701453
# 11     30510373  33098233       1675909  17053422  92.181274    9.827406
# ...

# %%
df.columns.tolist()
# Out:
# ['Num_Ans_Rep',
#  'Tot_Ans',
#  'Num_User_Rep',
#  'Tot_User',
#  'Frac_Ans',
#  'Frac_User',
#  'Rep_Cap']

# %%
df['avg_degree'] = df['Num_Ans_Rep']/df['Num_User_Rep']

# %%
df
# Out:
#     Num_Ans_Rep   Tot_Ans  Num_User_Rep  Tot_User   Frac_Ans   Frac_User  \
# 0        165053  33098233             4  17053422   0.498676    0.000023
# 1       3584549  33098233          1092  17053422  10.830031    0.006403
# 2      12257130  33098233         24894  17053422  37.032581    0.145977
# 3      21359160  33098233        171987  17053422  64.532629    1.008519
# 4      23106201  33098233        242731  17053422  69.810981    1.423357
# 5      25115466  33098233        366102  17053422  75.881592    2.146795
# 6      25776157  33098233        421002  17053422  77.877744    2.468724
# 7      26541380  33098233        497052  17053422  80.189719    2.914676
# 8      27457992  33098233        619500  17053422  82.959087    3.632702
# 9      27951264  33098233        714071  17053422  84.449415    4.187259
# 10     29426492  33098233       1142827  17053422  88.906535    6.701453
# 11     30510373  33098233       1675909  17053422  92.181274    9.827406
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df['Frac_User'],df['Frac_Ans'],marker='o')

# %%
df = pd.read_csv('freq_plot_data.csv')
df = df.sort_values(by='Frac_User')

df['Tot_User'] = 4222004 #total if reputation 1 users are ignored
df['Tot_Ans'] = 32101441 #total if reputation 1 users are ignored
df = df[df.Rep_Cap>0]

df['Frac_User'] = (df['Num_User_Rep']/df['Tot_User'])*100
df['Frac_Ans'] = (df['Num_Ans_Rep']/df['Tot_Ans'])*100

df
# Out:
#     Num_Ans_Rep   Tot_Ans  Num_User_Rep  Tot_User    Frac_Ans   Frac_User  \
# 0        165053  32101441             4   4222004    0.514161    0.000095
# 1       3584549  32101441          1092   4222004   11.166318    0.025864
# 2      12257130  32101441         24894   4222004   38.182492    0.589625
# 3      21359160  32101441        171987   4222004   66.536452    4.073587
# 4      23106201  32101441        242731   4222004   71.978703    5.749189
# 5      25115466  32101441        366102   4222004   78.237815    8.671285
# 6      25776157  32101441        421002   4222004   80.295950    9.971615
# 7      26541380  32101441        497052   4222004   82.679715   11.772893
# 8      27457992  32101441        619500   4222004   85.535076   14.673127
# 9      27951264  32101441        714071   4222004   87.071680   16.913082
# 10     29426492  32101441       1142827   4222004   91.667200   27.068354
# 11     30510373  32101441       1675909   4222004   95.043624   39.694633
# ...

# %%
plt.plot(df['Frac_User'],df['Frac_Ans'],marker='o')

# %%
df = pd.read_csv('freq_plot_data.csv')
df = df.sort_values(by='Frac_User')

df['Tot_User'] = 1675909 #total if reputation below 50 users are ignored
df['Tot_Ans'] = 30510373 #total if reputation below 50 users are ignored
df = df[df.Rep_Cap>=50]

df['Frac_User'] = (df['Num_User_Rep']/df['Tot_User'])*100
df['Frac_Ans'] = (df['Num_Ans_Rep']/df['Tot_Ans'])*100

df
# Out:
#     Num_Ans_Rep   Tot_Ans  Num_User_Rep  Tot_User    Frac_Ans   Frac_User  \
# 0        165053  30510373             4   1675909    0.540973    0.000239
# 1       3584549  30510373          1092   1675909   11.748624    0.065159
# 2      12257130  30510373         24894   1675909   40.173648    1.485403
# 3      21359160  30510373        171987   1675909   70.006224   10.262311
# 4      23106201  30510373        242731   1675909   75.732280   14.483543
# 5      25115466  30510373        366102   1675909   82.317794   21.844981
# 6      25776157  30510373        421002   1675909   84.483258   25.120815
# 7      26541380  30510373        497052   1675909   86.991332   29.658651
# 8      27457992  30510373        619500   1675909   89.995596   36.965014
# 9      27951264  30510373        714071   1675909   91.612331   42.607982
# 10     29426492  30510373       1142827   1675909   96.447500   68.191471
# 11     30510373  30510373       1675909   1675909  100.000000  100.000000
#
# ...

# %%
plt.plot(df['Frac_User'],df['Frac_Ans'],marker='o')
#among top 10 percent user, 20-80 holds

# %%
df = pd.read_csv('freq_plot_data.csv')
df = df.sort_values(by='Frac_User')

df['Tot_User'] = 1142827 #total if reputation below 100 users are ignored
df['Tot_Ans'] = 29426492 #total if reputation below 100 users are ignored
df = df[df.Rep_Cap>=100]

df['Frac_User'] = (df['Num_User_Rep']/df['Tot_User'])*100
df['Frac_Ans'] = (df['Num_Ans_Rep']/df['Tot_Ans'])*100

df
# Out:
#     Num_Ans_Rep   Tot_Ans  Num_User_Rep  Tot_User    Frac_Ans   Frac_User  \
# 0        165053  29426492             4   1142827    0.560899    0.000350
# 1       3584549  29426492          1092   1142827   12.181367    0.095553
# 2      12257130  29426492         24894   1142827   41.653385    2.178282
# 3      21359160  29426492        171987   1142827   72.584799   15.049259
# 4      23106201  29426492        242731   1142827   78.521765   21.239523
# 5      25115466  29426492        366102   1142827   85.349847   32.034770
# 6      25776157  29426492        421002   1142827   87.595072   36.838647
# 7      26541380  29426492        497052   1142827   90.195529   43.493197
# 8      27457992  29426492        619500   1142827   93.310450   54.207680
# 9      27951264  29426492        714071   1142827   94.986735   62.482860
# 10     29426492  29426492       1142827   1142827  100.000000  100.000000
#
#     Rep_Cap
# 0   1000000
# 1    100000
# 2     10000
# 3      1500
# ...

# %%
plt.plot(df['Frac_User'],df['Frac_Ans'],marker='o')
#among top 10 percent user, 20-80 holds

# %%
# Out:
# <class 'xml.etree.ElementTree.ElementTree'>

# %%
root = xmlparse.getroot()
len(root.getchildren())
# Out:
# /home/zm8bh/.conda/envs/skmob/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# 54741615

# %%
cnt = 5
for child in root:
    print(child.attrib)
    print("")
    cnt = cnt - 1
    if(cnt==0):
        break
# Out:
# {'Id': '4', 'PostTypeId': '1', 'AcceptedAnswerId': '7', 'CreationDate': '2008-07-31T21:42:52.667', 'Score': '742', 'ViewCount': '61738', 'Body': '<p>I want to use a <code>Track-Bar</code> to change a <code>Form</code>\'s opacity.</p>\n<p>This is my code:</p>\n<pre class="lang-cs prettyprint-override"><code>decimal trans = trackBar1.Value / 5000;\nthis.Opacity = trans;\n</code></pre>\n<p>When I build the application, it gives the following error:</p>\n<blockquote>\n<pre class="lang-none prettyprint-override"><code>Cannot implicitly convert type decimal to double\n</code></pre>\n</blockquote>\n<p>I have tried using <code>trans</code> and <code>double</code>, but then the <code>Control</code> doesn\'t work. This code worked fine in a past VB.NET project.</p>\n', 'OwnerUserId': '8', 'LastEditorUserId': '3072350', 'LastEditorDisplayName': 'Rich B', 'LastEditDate': '2021-02-26T03:31:15.027', 'LastActivityDate': '2021-11-15T21:15:29.713', 'Title': 'How to convert a Decimal to a Double in C#
# ...
